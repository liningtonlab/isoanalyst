# %%
import pandas as pd

cat_df = pd.read_csv("IsotopeDataProcessing/CAT/RLUS1353_All_features.csv").sort_values(["RetTime", "PrecMz"])
j1_df = pd.read_csv("IsotopeDataProcessing/J1/RLUS1353_All_features.csv").sort_values(["RetTime", "PrecMz"])
j2_df = pd.read_csv("IsotopeDataProcessing/J2/RLUS1353_All_features.csv").sort_values(["RetTime", "PrecMz"])
j3_df = pd.read_csv("IsotopeDataProcessing/J3/RLUS1353_All_features.csv").sort_values(["RetTime", "PrecMz"])

# %%
# Ran in ~180-190 s
print(cat_df.shape)
cat_df.head(10)
# Out:
# (4188, 9)
#          reps          Sample    PrecMz  PrecZ  RetTime  rep_count  LowScan  \
# 3211   GLU_14   RLUS135314GLU  298.8808      1    0.357        4.0     43.0
# 0       ACE_4   RLUS135312ACE  298.8795      1    0.360        3.0     41.0
# 25     ACE_75   RLUS135312ACE  262.9280      1    0.365        3.0     44.0
# 2153   MET_49   RLUS135312MET  262.9290      1    0.365        3.0     44.0
# 3225   GLU_59   RLUS135314GLU  262.9276      1    0.367        3.0     43.0
# 1145  PROP_26  RLUS135312PROP  474.9184      1    0.367        3.0     44.0
# 2157   MET_58   RLUS135312MET  506.8729      1    0.367        3.0     44.0
# 2164   MET_65   RLUS135312MET  634.8354      1    0.368        3.0     44.0
# 3216   GLU_38   RLUS135314GLU  474.9195      1    0.369        4.0     44.0
# 1148  PROP_29  RLUS135312PROP  490.8950      1    0.369        3.0     44.0
#
#       HighScan         Exp_ID
# 3211      52.0     RLUS1353_1
# 0         50.0     RLUS1353_1
# ...

# %%
# Ran in ~180-190 s
print(j1_df.shape)
j1_df.head(10)
# Out:
# (4188, 8)
#               Sample    PrecMz  RetTime  PrecZ  LowScan  HighScan     reps  \
# 3496   RLUS135314GLU  298.8808    0.357      1       43        52   GLU_14
# 798    RLUS135312ACE  298.8795    0.360      1       41        50    ACE_4
# 1004   RLUS135312ACE  262.9280    0.365      1       44        55   ACE_75
# 2882   RLUS135312MET  262.9290    0.365      1       44        54   MET_49
# 3913   RLUS135314GLU  262.9276    0.367      1       43        54   GLU_59
# 1685  RLUS135312PROP  474.9184    0.367      1       44        52  PROP_26
# 2939   RLUS135312MET  506.8729    0.367      1       44        53   MET_58
# 2981   RLUS135312MET  634.8354    0.368      1       44        53   MET_65
# 3801   RLUS135314GLU  474.9195    0.369      1       44        52   GLU_38
# 1705  RLUS135312PROP  490.8950    0.369      1       44        52  PROP_29
#
#              Exp_ID
# 3496   RLUS1353_799
# 798    RLUS1353_799
# 1004  RLUS1353_1005
# 2882  RLUS1353_1005
# 3913  RLUS1353_1005
# ...

# %%
# Ran in ~60-70 s
print(j2_df.shape)
j2_df.head(10)
# Out:
# (4650, 9)
#       RetTime    PrecMz  PrecZ  \
# 1257    0.356  298.8802    1.0
# 3578    0.357  298.8808    1.0
# 0       0.360  298.8795    1.0
# 28      0.365  262.9280    1.0
# 2410    0.365  262.9290    1.0
# 1258    0.365  746.8535    1.0
# 3594    0.367  262.9276    1.0
# 1266    0.367  474.9184    1.0
# 2414    0.367  506.8729    1.0
# 2421    0.368  634.8354    1.0
#
#                                                bin_info  \
# 1257  {"RetTime": [0.34700000000000003, 0.36], "Prec...
# 3578  {"RetTime": [0.34700000000000003, 0.36], "Prec...
# 0     {"RetTime": [0.36, 0.361], "PrecMz": [298.8774...
# 28    {"RetTime": [0.36, 0.368], "PrecMz": [262.9274...
# 2410  {"RetTime": [0.36, 0.368], "PrecMz": [262.9285...
# 1258  {"RetTime": [0.36, 0.36700000000000005], "Prec...
# 3594  {"RetTime": [0.36700000000000005, 0.368], "Pre...
# 1266  {"RetTime": [0.36700000000000005, 0.368], "Pre...
# 2414  {"RetTime": [0.36700000000000005, 0.368], "Pre...
# ...

# %%
# Ran in ~700 s...
print(j3_df.shape)
j3_df.head(10)
# Out:
# (4241, 8)
#               Sample    PrecMz  RetTime  PrecZ  LowScan  HighScan     reps  \
# 3548   RLUS135314GLU  298.8808    0.357      1       43        52   GLU_14
# 791    RLUS135312ACE  298.8795    0.360      1       41        50    ACE_4
# 1007   RLUS135312ACE  262.9280    0.365      1       44        55   ACE_75
# 2909   RLUS135312MET  262.9290    0.365      1       44        54   MET_49
# 3952   RLUS135314GLU  262.9276    0.367      1       43        54   GLU_59
# 1710  RLUS135312PROP  474.9184    0.367      1       44        52  PROP_26
# 2968   RLUS135312MET  506.8729    0.367      1       44        53   MET_58
# 3010   RLUS135312MET  634.8354    0.368      1       44        53   MET_65
# 3833   RLUS135314GLU  474.9195    0.369      1       44        52   GLU_38
# 1722  RLUS135312PROP  490.8950    0.369      1       44        52  PROP_29
#
#              Exp_ID
# 3548   RLUS1353_792
# 791    RLUS1353_792
# 1007  RLUS1353_1008
# 2909  RLUS1353_1008
# 3952  RLUS1353_1008
# ...

# %%
print(len(j1_df.Exp_ID.unique()))
print(len(j2_df.Exp_ID.unique()))
print(len(j3_df.Exp_ID.unique()))
# Out:
# 2749
# 3033
# 2773

# %%
j2_df[j2_df['Exp_ID']=='RLUS1353_1258']

# %%
# for i in j2_df.iloc[:11].RetTime.unique():
#     print("Jeff")
#     display(j2_df[j2_df['RetTime'] == i])
#     print("Cat")
#     display(cat_df[pd.np.isclose(cat_df['RetTime'], i)])
